# %%
# Importing Necessary Library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly as py
import plotly.graph_objects as go
from prophet import Prophet

# %%
# load the data
df  = pd.read_csv('covid_19_clean_complete.csv')

# %%
# checking 5 five rows & shape
print(df.shape)
df.head()
# Out:
# (49068, 10)
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %% [markdown]
# ## **Data Columns Overview:**
#
# Province/State: Contains data for specific regions in some
# countries, but many values are missing (only 14,664 non-null).
#
# Country/Region: The country or region name (49,068 non-null)
#
# Lat and Long: Latitude and Longitude coordinates for the location (complete, non-null)
#
# Date: The date when the data was recorded (complete, but stored as an object, likely needs conversion to datetime)
#
# Confirmed: The total number of confirmed COVID-19 cases (49,068 non-null)
#
# Deaths: The total number of deaths due to COVID-19 (49,068 non-null)
#
# Recovered: The total number of recoveries (49,068 non-null).
# Active: Active cases (calculated as confirmed - deaths - recovered)
#
# WHO Region: The WHO classification for regions (49,068 non-null)

# %%
# covert date column to datetime
df['Date']  =pd.to_datetime(df['Date'])

# %%
# Handling missing Province/State
df['Province/State'].fillna('Unknown', inplace=True)
# Out:
# <ipython-input-6-701b6dab6e48>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Province/State'].fillna('Unknown', inplace=True)

# %%
# cheking null values
df.isnull().sum()
# Out:
# Province/State    0
# Country/Region    0
# Lat               0
# Long              0
# Date              0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# WHO Region        0
# dtype: int64

# %%
df.describe().T
# Out:
#              count                 mean                  min  \
# Lat        49068.0             21.43373             -51.7963
# Long       49068.0            23.528236               -135.0
# Date         49068  2020-04-24 12:00:00  2020-01-22 00:00:00
# Confirmed  49068.0         16884.904255                  0.0
# Deaths     49068.0            884.17916                  0.0
# Recovered  49068.0          7915.713479                  0.0
# Active     49068.0          8085.011617                -14.0
#
#                            25%                  50%                  75%  \
# Lat                   7.873054              23.6345             41.20438
# Long                  -15.3101              21.7453            80.771797
# Date       2020-03-08 18:00:00  2020-04-24 12:00:00  2020-06-10 06:00:00
# Confirmed                  4.0                168.0              1518.25
# Deaths                     0.0                  2.0                 30.0
# Recovered                  0.0                 29.0                666.0
# Active                     0.0                 26.0                606.0
#
#                            max            std
# Lat                    71.7069       24.95032
# Long                   178.065       70.44274
# Date       2020-07-27 00:00:00            NaN
# Confirmed            4290259.0  127300.205272
# Deaths                148011.0    6313.584411
# Recovered            1846641.0   54800.918731
# Active               2816444.0   76258.903026

# %%
# Covid Cases
cases = ['Confirmed','Deaths','Recovered','Active']

# Active cases
df['Active'] = df['Confirmed']- df['Deaths']- df['Recovered']

# %%
# calculating the total sum of 'Confirmed', 'Deaths', 'Recovered', and 'Active' cases grouped by 'Date'.
temp = df.groupby('Date')[['Confirmed', 'Deaths', 'Recovered', 'Active']].sum().reset_index()
temp = temp[temp['Date']==max(temp['Date'])].reset_index(drop=True)
temp.style.background_gradient(cmap='Pastel1')
# Out:
# <style type="text/css">
# #T_c1c00_row0_col1, #T_c1c00_row0_col2, #T_c1c00_row0_col3, #T_c1c00_row0_col4 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# </style>
# <table id="T_c1c00" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1c00_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_c1c00_level0_col1" class="col_heading level0 col1" >Confirmed</th>
#       <th id="T_c1c00_level0_col2" class="col_heading level0 col2" >Deaths</th>
#       <th id="T_c1c00_level0_col3" class="col_heading level0 col3" >Recovered</th>
#       <th id="T_c1c00_level0_col4" class="col_heading level0 col4" >Active</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1c00_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1c00_row0_col0" class="data row0 col0" >2020-07-27 00:00:00</td>
#       <td id="T_c1c00_row0_col1" class="data row0 col1" >16480485</td>
#       <td id="T_c1c00_row0_col2" class="data row0 col2" >654036</td>
#       <td id="T_c1c00_row0_col3" class="data row0 col3" >9468087</td>
#       <td id="T_c1c00_row0_col4" class="data row0 col4" >6358362</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Total Confirmed , Death, Recovered, Actives Cases by Country/region
full_latest = df[df['Date'] == max(df['Date'])].reset_index()
full_latest_grouped = full_latest.groupby('Country/Region')[['Confirmed', 'Deaths', 'Recovered', 'Active']].sum().reset_index()
lastest_df = full_latest_grouped.sort_values(by='Confirmed', ascending=False)
lastest_df = lastest_df.reset_index(drop=True)
lastest_df.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_2495f_row0_col1, #T_2495f_row0_col2, #T_2495f_row0_col4, #T_2495f_row1_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_2495f_row0_col3 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_2495f_row1_col1 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_2495f_row1_col2 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_2495f_row1_col4 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_2495f_row2_col1 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_2495f_row2_col2 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_2495f_row2_col3 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_2495f_row2_col4 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_2495f_row3_col1 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_2495f_row3_col2, #T_2495f_row5_col1, #T_2495f_row6_col1, #T_2495f_row8_col4 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_2495f_row3_col3 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_2495f_row3_col4, #T_2495f_row8_col1, #T_2495f_row13_col3 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_2495f_row4_col1, #T_2495f_row9_col2, #T_2495f_row14_col3 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_2495f_row4_col2, #T_2495f_row18_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_2495f_row4_col3 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_2495f_row4_col4, #T_2495f_row7_col2, #T_2495f_row13_col1, #T_2495f_row13_col2, #T_2495f_row18_col2, #T_2495f_row20_col2 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_2495f_row5_col2 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_2495f_row5_col3 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_2495f_row5_col4, #T_2495f_row12_col2, #T_2495f_row24_col3, #T_2495f_row24_col4, #T_2495f_row27_col1, #T_2495f_row27_col4, #T_2495f_row28_col1, #T_2495f_row28_col3, #T_2495f_row29_col1, #T_2495f_row30_col1, #T_2495f_row31_col1, #T_2495f_row31_col2, #T_2495f_row31_col4, #T_2495f_row32_col1, #T_2495f_row33_col1, #T_2495f_row36_col3, #T_2495f_row38_col3, #T_2495f_row40_col4, #T_2495f_row42_col3, #T_2495f_row44_col3, #T_2495f_row45_col3, #T_2495f_row51_col3, #T_2495f_row52_col3 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_2495f_row6_col2 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_2495f_row6_col3 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_2495f_row6_col4, #T_2495f_row11_col4, #T_2495f_row16_col4, #T_2495f_row19_col4, #T_2495f_row23_col2, #T_2495f_row23_col3, #T_2495f_row24_col2, #T_2495f_row25_col2, #T_2495f_row32_col3 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_2495f_row7_col1, #T_2495f_row11_col3 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_2495f_row7_col3 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_2495f_row7_col4, #T_2495f_row14_col4, #T_2495f_row26_col2, #T_2495f_row30_col4, #T_2495f_row36_col2, #T_2495f_row42_col4, #T_2495f_row43_col4, #T_2495f_row44_col4, #T_2495f_row46_col2, #T_2495f_row49_col2, #T_2495f_row53_col1, #T_2495f_row54_col1, #T_2495f_row54_col2, #T_2495f_row55_col1, #T_2495f_row56_col1, #T_2495f_row57_col1, #T_2495f_row58_col1, #T_2495f_row59_col1, #T_2495f_row59_col2, #T_2495f_row60_col1, #T_2495f_row60_col3, #T_2495f_row61_col1, #T_2495f_row62_col1, #T_2495f_row62_col2, #T_2495f_row63_col1, #T_2495f_row63_col3, #T_2495f_row64_col1, #T_2495f_row64_col3, #T_2495f_row65_col1, #T_2495f_row66_col3, #T_2495f_row67_col4, #T_2495f_row68_col3, #T_2495f_row69_col3, #T_2495f_row70_col3, #T_2495f_row71_col3, #T_2495f_row73_col3, #T_2495f_row74_col2, #T_2495f_row74_col3, #T_2495f_row75_col2, #T_2495f_row82_col3, #T_2495f_row83_col3, #T_2495f_row99_col2 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_2495f_row8_col2 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_2495f_row8_col3, #T_2495f_row15_col4, #T_2495f_row18_col4, #T_2495f_row20_col3, #T_2495f_row22_col2, #T_2495f_row22_col4, #T_2495f_row25_col4, #T_2495f_row29_col3, #T_2495f_row30_col2, #T_2495f_row32_col2, #T_2495f_row32_col4, #T_2495f_row35_col2, #T_2495f_row35_col4, #T_2495f_row37_col2, #T_2495f_row39_col2, #T_2495f_row39_col4, #T_2495f_row40_col3, #T_2495f_row41_col2, #T_2495f_row41_col4, #T_2495f_row45_col4, #T_2495f_row47_col3, #T_2495f_row48_col2, #T_2495f_row48_col4, #T_2495f_row49_col4, #T_2495f_row50_col4, #T_2495f_row51_col4, #T_2495f_row52_col2, #T_2495f_row52_col4, #T_2495f_row53_col4, #T_2495f_row54_col4, #T_2495f_row55_col2, #T_2495f_row55_col4, #T_2495f_row56_col4, #T_2495f_row57_col4, #T_2495f_row58_col2, #T_2495f_row58_col3, #T_2495f_row59_col4, #T_2495f_row60_col2, #T_2495f_row60_col4, #T_2495f_row61_col2, #T_2495f_row61_col4, #T_2495f_row62_col4, #T_2495f_row63_col2, #T_2495f_row63_col4, #T_2495f_row64_col2, #T_2495f_row64_col4, #T_2495f_row65_col2, #T_2495f_row65_col4, #T_2495f_row66_col1, #T_2495f_row66_col2, #T_2495f_row66_col4, #T_2495f_row67_col1, #T_2495f_row67_col2, #T_2495f_row67_col3, #T_2495f_row68_col1, #T_2495f_row68_col2, #T_2495f_row68_col4, #T_2495f_row69_col1, #T_2495f_row69_col2, #T_2495f_row69_col4, #T_2495f_row70_col1, #T_2495f_row70_col2, #T_2495f_row70_col4, #T_2495f_row71_col1, #T_2495f_row71_col2, #T_2495f_row71_col4, #T_2495f_row72_col1, #T_2495f_row72_col2, #T_2495f_row72_col3, #T_2495f_row72_col4, #T_2495f_row73_col1, #T_2495f_row73_col2, #T_2495f_row73_col4, #T_2495f_row74_col1, #T_2495f_row74_col4, #T_2495f_row75_col1, #T_2495f_row75_col3, #T_2495f_row75_col4, #T_2495f_row76_col1, #T_2495f_row76_col2, #T_2495f_row76_col3, #T_2495f_row76_col4, #T_2495f_row77_col1, #T_2495f_row77_col2, #T_2495f_row77_col3, #T_2495f_row77_col4, #T_2495f_row78_col1, #T_2495f_row78_col2, #T_2495f_row78_col3, #T_2495f_row78_col4, #T_2495f_row79_col1, #T_2495f_row79_col2, #T_2495f_row79_col3, #T_2495f_row79_col4, #T_2495f_row80_col1, #T_2495f_row80_col2, #T_2495f_row80_col3, #T_2495f_row80_col4, #T_2495f_row81_col1, #T_2495f_row81_col2, #T_2495f_row81_col3, #T_2495f_row81_col4, #T_2495f_row82_col1, #T_2495f_row82_col2, #T_2495f_row82_col4, #T_2495f_row83_col1, #T_2495f_row83_col2, #T_2495f_row83_col4, #T_2495f_row84_col1, #T_2495f_row84_col2, #T_2495f_row84_col3, #T_2495f_row84_col4, #T_2495f_row85_col1, #T_2495f_row85_col2, #T_2495f_row85_col3, #T_2495f_row85_col4, #T_2495f_row86_col1, #T_2495f_row86_col2, #T_2495f_row86_col3, #T_2495f_row86_col4, #T_2495f_row87_col1, #T_2495f_row87_col2, #T_2495f_row87_col3, #T_2495f_row87_col4, #T_2495f_row88_col1, #T_2495f_row88_col2, #T_2495f_row88_col3, #T_2495f_row88_col4, #T_2495f_row89_col1, #T_2495f_row89_col2, #T_2495f_row89_col3, #T_2495f_row89_col4, #T_2495f_row90_col1, #T_2495f_row90_col2, #T_2495f_row90_col3, #T_2495f_row90_col4, #T_2495f_row91_col1, #T_2495f_row91_col2, #T_2495f_row91_col3, #T_2495f_row91_col4, #T_2495f_row92_col1, #T_2495f_row92_col2, #T_2495f_row92_col3, #T_2495f_row92_col4, #T_2495f_row93_col1, #T_2495f_row93_col2, #T_2495f_row93_col3, #T_2495f_row93_col4, #T_2495f_row94_col1, #T_2495f_row94_col2, #T_2495f_row94_col3, #T_2495f_row94_col4, #T_2495f_row95_col1, #T_2495f_row95_col2, #T_2495f_row95_col3, #T_2495f_row95_col4, #T_2495f_row96_col1, #T_2495f_row96_col2, #T_2495f_row96_col3, #T_2495f_row96_col4, #T_2495f_row97_col1, #T_2495f_row97_col2, #T_2495f_row97_col3, #T_2495f_row97_col4, #T_2495f_row98_col1, #T_2495f_row98_col2, #T_2495f_row98_col3, #T_2495f_row98_col4, #T_2495f_row99_col1, #T_2495f_row99_col3, #T_2495f_row99_col4, #T_2495f_row100_col1, #T_2495f_row100_col2, #T_2495f_row100_col3, #T_2495f_row100_col4, #T_2495f_row101_col1, #T_2495f_row101_col2, #T_2495f_row101_col3, #T_2495f_row101_col4, #T_2495f_row102_col1, #T_2495f_row102_col2, #T_2495f_row102_col3, #T_2495f_row102_col4, #T_2495f_row103_col1, #T_2495f_row103_col2, #T_2495f_row103_col3, #T_2495f_row103_col4, #T_2495f_row104_col1, #T_2495f_row104_col2, #T_2495f_row10 ...

# %%
# Top 10 Countries That has most Active Cases
lastest_df[0:10]['Country/Region']
# Out:
# 0                US
# 1            Brazil
# 2             India
# 3            Russia
# 4      South Africa
# 5            Mexico
# 6              Peru
# 7             Chile
# 8    United Kingdom
# 9              Iran
# Name: Country/Region, dtype: object

# %%
# Global time series by summing up data for all countries
df_global = df.groupby('Date').sum().reset_index()

# Plot cases globally over time
import plotly.express as px

fig = px.line(df_global, x='Date', y='Confirmed', title='Global Confirmed COVID-19 Cases Over Time')
fig.show()

fig = px.line(df_global, x='Date', y='Active', title='Global Active COVID-19 Cases Over Time')
fig.show()

fig = px.line(df_global, x='Date', y='Deaths', title='Global Death COVID-19 Cases Over Time')
fig.show()

fig = px.line(df_global, x='Date', y='Recovered', title='Global Recovered COVID-19 Cases Over Time')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id
T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:0 ...

# %%
# Prepare data for Prophet (confirmed cases)
confirmed = df[['Date', 'Confirmed']].rename(columns={'Date': 'ds', 'Confirmed': 'y'})

# Initialize the Prophet model
model = Prophet()
model.fit(confirmed)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7b9v1ioq/xcwxu66q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7b9v1ioq/cfka6s3m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5514', 'data', 'file=/tmp/tmp7b9v1ioq/xcwxu66q.json', 'init=/tmp/tmp7b9v1ioq/cfka6s3m.json', 'output', 'file=/tmp/tmp7b9v1ioq/prophet_modelwplwz5gm/prophet_model-20241128103252.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:32:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:32:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
confirmed.tail()
# Out:
#               ds     y
# 49063 2020-07-27   865
# 49064 2020-07-27  1691
# 49065 2020-07-27   354
# 49066 2020-07-27  7235
# 49067 2020-07-27   505

# %%
# Predict future cases for the next 7 days
future = model.make_future_dataframe(periods=7)
forecast = model.predict(future)

# Visualize forecast
fig = model.plot(forecast)
ax = fig.gca()
ax.set_title('Confirmed Cases Forecast')
fig.show()

# %%
# 7 Day Forcast
forecast.tail(10)
# Out:
#             ds         trend     yhat_lower     yhat_upper   trend_lower  \
# 185 2020-07-25  59988.409663 -101558.566913  218304.218271  59988.409663
# 186 2020-07-26  60752.453953 -102312.648660  218831.559056  60752.453953
# 187 2020-07-27  61516.498243 -100780.380512  221454.955018  61516.498243
# 188 2020-07-28  62280.542533 -101808.264003  210996.163525  62280.542533
# 189 2020-07-29  63044.586823 -106902.162082  224324.473039  63038.200440
# 190 2020-07-30  63808.631113  -92850.261270  229165.224156  63782.339049
# 191 2020-07-31  64572.675402  -90198.469037  224939.388702  64521.513069
# 192 2020-08-01  65336.719692  -74671.402627  235719.647048  65254.122886
# 193 2020-08-02  66100.763982 -102699.830594  223131.993768  65983.643705
# 194 2020-08-03  66864.808272 -101433.197877  219959.417081  66710.202071
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 185  59988.409663       57.971967             57.971967             57.971967
# 186  60752.453953       36.844386             36.844386             36.844386
# 187  61516.498243        0.918308              0.918308              0.918308
# 188  62280.542533      -77.940383            -77.940383            -77.940383
# 189  63046.745560      -44.131911            -44.131911            -44.131911
# 190  63826.613470       -7.814878             -7.814878             -7.814878
# 191  64610.924413       34.152512             34.152512             34.152512
# 192  65400.618318       57.971967             57.971967             57.971967
# 193  66195.211171       36.844386             36.844386             36.844386
# 194  67005.233610        0.918308              0.918308              0.918308
#
#         weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 185  57.971967     57.971967     57.971967                   0.0
# 186  36.844386     36.844386     36.844386                   0.0
# 187   0.918308      0.918308      0.918308                   0.0
# 188 -77.940383    -77.940383    -77.940383                   0.0
# 189 -44.131911    -44.131911    -44.131911                   0.0
# 190  -7.814878     -7.814878     -7.814878                   0.0
# 191  34.152512     34.152512     34.152512                   0.0
# 192  57.971967     57.971967     57.971967                   0.0
# 193  36.844386     36.844386     36.844386                   0.0
# 194   0.918308      0.918308      0.918308                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 185                         0.0                         0.0  60046.381630
# 186                         0.0                         0.0  60789.298339
# 187                         0.0                         0.0  61517.416551
# 188                         0.0                         0.0  62202.602150
# 189                         0.0                         0.0  63000.454911
# 190                         0.0                         0.0  63800.816234
# 191                         0.0                         0.0  64606.827914
# 192                         0.0                         0.0  65394.691659
# 193                         0.0                         0.0  66137.608369
# 194                         0.0                         0.0  66865.726580

# %%
# Prepare data for Prophet (Death cases)
death = df[['Date', 'Deaths']].rename(columns={'Date': 'ds', 'Deaths': 'y'})

# Initialize the Prophet model
model = Prophet()
model.fit(death)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7b9v1ioq/znfnc_fx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7b9v1ioq/8r0sze0z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99963', 'data', 'file=/tmp/tmp7b9v1ioq/znfnc_fx.json', 'init=/tmp/tmp7b9v1ioq/8r0sze0z.json', 'output', 'file=/tmp/tmp7b9v1ioq/prophet_model05g5qb9a/prophet_model-20241128103459.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:34:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:35:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Predict future cases for the next 7 days
future = model.make_future_dataframe(periods=7)
forecast = model.predict(future)

# Visualize forecast
fig = model.plot(forecast)
ax = fig.gca()
ax.set_title('Death Cases Forecast')
fig.show()

# %%
# Predict future cases for the next 7 days
future = model.make_future_dataframe(periods=7)
forecast = model.predict(future)

# Visualize forecast
fig = model.plot(forecast)
ax = fig.gca()
ax.set_title('Recovered Cases Forecast')
fig.show()

# %%
# Prepare data for Prophet (Active cases)
active= df[['Date', 'Active']].rename(columns={'Date': 'ds', 'Active': 'y'})

# Initialize the Prophet model
model = Prophet()
model.fit(active)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7b9v1ioq/ikymtjv8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7b9v1ioq/6vs3d3pd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56378', 'data', 'file=/tmp/tmp7b9v1ioq/ikymtjv8.json', 'init=/tmp/tmp7b9v1ioq/6vs3d3pd.json', 'output', 'file=/tmp/tmp7b9v1ioq/prophet_modelqduei05q/prophet_model-20241128103607.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:36:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:36:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Predict future cases for the next 7 days
future = model.make_future_dataframe(periods=7)
forecast = model.predict(future)

# Visualize forecast
fig = model.plot(forecast)
ax = fig.gca()
ax.set_title('Active Cases Forecast')
fig.show()
